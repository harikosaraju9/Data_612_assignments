# %% [markdown]
# <a href="https://colab.research.google.com/github/harikosaraju9/Data_612_assignments/blob/main/Data_mining_week_1_Hari_Kosaraju.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# 1. Select dataset of your choice.
#
# Selected 'State_Drug_Utilization_Data_2010' dataset.

# %%
df_card = pd.read_csv("State_Drug_Utilization_Data_2010_Hari.csv")

# %% [markdown]
# 2a. Show the .head() and .tail() of the data set. Specify the number of rows to print using .head() and .tail().

# %%
df_card.head()
# Out:
#    Unnamed: 0 Utilization Type  ...             Location          NDC
# 0      128037             FFSU  ...  (35.5376, -96.9247)  50458055101
# 1      491755             FFSU  ...  (40.3363, -89.0022)    378261010
# 2     2568076             FFSU  ...   (18.2766, -66.335)  50242006201
# 3      491263             FFSU  ...  (44.0407, -72.7093)     93738201
# 4      836489             MCOU  ...  (43.3504, -84.5603)    904198359
#
# [5 rows x 21 columns]

# %%
df_card.tail()
# Out:
#         Unnamed: 0 Utilization Type  ...             Location          NDC
# 156214      317999             FFSU  ...  (41.6772, -71.5101)  49884060085
# 156215     2752214             FFSU  ...   (40.5773, -77.264)    182101701
# 156216     2519195             FFSU  ...   (40.314, -74.5089)    536322301
# 156217      815768             MCOU  ...  (39.3498, -75.5148)    781119110
# 156218     2029158             MCOU  ...  (41.1289, -98.2883)     54472825
#
# [5 rows x 21 columns]

# %%
df_card.head(25)
# Out:
#     Unnamed: 0 Utilization Type  ...              Location          NDC
# 0       128037             FFSU  ...   (35.5376, -96.9247)  50458055101
# 1       491755             FFSU  ...   (40.3363, -89.0022)    378261010
# 2      2568076             FFSU  ...    (18.2766, -66.335)  50242006201
# 3       491263             FFSU  ...   (44.0407, -72.7093)     93738201
# 4       836489             MCOU  ...   (43.3504, -84.5603)    904198359
# 5      2468555             FFSU  ...    (37.669, -84.6514)    409792609
# 6        73349             FFSU  ...    (38.4623, -92.302)    245016806
# 7      1166159             FFSU  ...   (39.3498, -75.5148)  51672126403
# 8      2326672             FFSU  ...                   NaN     67004690
# 9       413825             FFSU  ...   (35.5376, -96.9247)  49884064101
# 10     3063756             FFSU  ...   (39.8647, -86.2604)  49348064573
# 11      925255             FFSU  ...    (38.4623, -92.302)     78043405
# ...

# %%
df_card.tail(25)
# Out:
#         Unnamed: 0 Utilization Type  ...              Location          NDC
# 156194      272598             FFSU  ...   (44.6074, -69.3977)    781513201
# 156195     2109314             FFSU  ...  (40.1135, -111.8535)  59762152002
# 156196     2204932             FFSU  ...   (39.8647, -86.2604)  45802042335
# 156197      341994             FFSU  ...  (33.7712, -111.3877)  63857041211
# 156198     2932015             FFSU  ...   (44.2853, -99.4632)    409263401
# 156199     1218868             FFSU  ...    (47.5362, -99.793)  50458003605
# 156200     2824398             FFSU  ...   (43.3504, -84.5603)    172541310
# 156201      158467             FFSU  ...    (31.106, -97.6475)    143145010
# 156202      920256             FFSU  ...                   NaN    378609001
# 156203      705101             FFSU  ...   (34.9513, -92.3809)    378262501
# 156204     2517256             FFSU  ...    (40.314, -74.5089)  13668001405
# ...

# %% [markdown]
# 2b. Print the column names.

# %%
df_card.columns
# Out:
# Index(['Unnamed: 0', 'Utilization Type', 'State', 'Labeler Code',
#        'Product Code', 'Package Size', 'Year', 'Quarter', 'Product Name',
#        'Units Reimbursed', 'Suppression Used', 'Number of Prescriptions',
#        'Total Amount Reimbursed', 'Medicaid Amount Reimbursed',
#        'Non Medicaid Amount Reimbursed', 'Quarter Begin', 'Quarter Begin Date',
#        'Latitude', 'Longitude', 'Location', 'NDC'],
#       dtype='object')

# %% [markdown]
# 2c. Print to see what is the type of your data set

# %%
print(type(df_card))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df_card.dtypes
# Out:
# Unnamed: 0                          int64
# Utilization Type                   object
# State                              object
# Labeler Code                        int64
# Product Code                        int64
# Package Size                        int64
# Year                                int64
# Quarter                             int64
# Product Name                       object
# Units Reimbursed                  float64
# Suppression Used                     bool
# Number of Prescriptions           float64
# Total Amount Reimbursed           float64
# Medicaid Amount Reimbursed        float64
# Non Medicaid Amount Reimbursed    float64
# Quarter Begin                      object
# Quarter Begin Date                 object
# Latitude                          float64
# Longitude                         float64
# Location                           object
# NDC                                 int64
# dtype: object

# %% [markdown]
# 2d. Check number of rows and columns.

# %%
df_card.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156219 entries, 0 to 156218
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unnamed: 0                      156219 non-null  int64
#  1   Utilization Type                156219 non-null  object
#  2   State                           156219 non-null  object
#  3   Labeler Code                    156219 non-null  int64
#  4   Product Code                    156219 non-null  int64
#  5   Package Size                    156219 non-null  int64
#  6   Year                            156219 non-null  int64
#  7   Quarter                         156219 non-null  int64
#  8   Product Name                    156192 non-null  object
#  9   Units Reimbursed                77002 non-null   float64
#  10  Suppression Used                156219 non-null  bool
#  11  Number of Prescriptions         77002 non-null   float64
# ...

# %% [markdown]
# 2e. Use groupby() and find the mean on your selected colum/s.

# %%
df_card.groupby(['Year','State'])[['Total Amount Reimbursed','Medicaid Amount Reimbursed']].mean()
# Out:
#             Total Amount Reimbursed  Medicaid Amount Reimbursed
# Year State
# 2010 AK                11408.481972                11102.460704
#      AL                13416.917323                12625.494960
#      AR                13320.762429                12854.746121
#      AZ                13999.419601                13785.993194
#      CA                63457.019749                62893.631247
#      CO                13272.978417                12926.654790
#      CT                20064.316073                19283.001752
#      DC                 7019.383893                 6889.744743
#      DE                 8682.086630                 8187.012551
#      FL                33154.226275                31928.109018
#      GA                15766.380699                14492.211293
#      HI                33764.644798                33764.390296
#      IA                 9650.866697                 8826.987967
# ...
